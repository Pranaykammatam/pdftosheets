# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranaykammatam/pdftosheets/blob/main/files/pdf_to_Googlesheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdfplumber gspread pandas google-auth

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3247117c-8352-43bb-8060-fc7a2c92cc62" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3247117c-8352-43bb-8060-fc7a2c92cc62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pdfplumber
import pandas as pd

pdf_file = list(uploaded.keys())[0]

all_tables = []

with pdfplumber.open(pdf_file) as pdf:
    for page in pdf.pages:
        tables = page.extract_tables()
        for table in tables:
            if table:
                all_tables.append(table)

print(f"Tables found: {len(all_tables)}")
# Out:
# Tables found: 1

# %%
dfs = []

for table in all_tables:
    df = pd.DataFrame(table[1:], columns=table[0])  # first row = header
    dfs.append(df)

# Preview first table
dfs[0].head()
# Out:
#       Name Age      City
# 0    Alice  25  New York
# 1      Bob  30    London
# 2  Charlie  28    Sydney

# %%
import gspread
from google.auth import default

creds, _ = default()
gc = gspread.authorize(creds)

# %%
sheet = gc.create("PDF Table Output")
worksheet = sheet.sheet1

print("Sheet URL:", sheet.url)
# Out:
# Sheet URL: https://docs.google.com/spreadsheets/d/1hrcOde6T57TdwF5bE0n_mX2226GoH6Ote3OUfu75FKU

# %%
worksheet.update([df.columns.values.tolist()] + df.values.tolist())
# Out:
# /tmp/ipykernel_236/3882759665.py:6: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   worksheet.update(
